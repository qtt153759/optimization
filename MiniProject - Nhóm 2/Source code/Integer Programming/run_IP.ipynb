# %%
# !pip install ortools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import ortools
from ortools.linear_solver import pywraplp

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/MiniProject/Project/IP
# Out:
# /content/drive/MyDrive/MiniProject/Project/IP

# %%
import os
import glob

# %%
output_dir = "Output"
if os.path.exists(output_dir) == False:
  os.mkdir("Output")
for i in range(2, 5):
  for path in glob.glob(f"Data/Type{i}*/**.txt"):
      t, name = path.split("/")[-2:]
      print(t, name)
      if os.path.exists(f"Output/{t}") == False:
          os.mkdir(f"Output/{t}")
      # if os.path.exists(f"Resul_with_time_limit/{t}/{name}") == False:
      os.system(f"python IP.py --input_file Data/{t}/{name} --output_file Output/{t}/{name}")
# Out:
# Type3Small 10-10-15.txt
# Type3Small 10-20-30.txt
# Type3Small 10-35-50.txt
# Type3Small 10-50-75.txt
# Type3Small 20-10-15.txt
# Type3Small 20-20-30.txt
# Type3Small 20-35-50.txt
# Type3Small 20-50-75.txt
# Type3Small 40-10-15.txt
# Type3Small 40-20-30.txt
# Type3Small 40-35-50.txt
# Type3Small 40-50-75.txt
# Type3Small 60-10-15.txt
# Type3Small 60-20-30.txt
# Type3Small 60-35-50.txt
# Type3Small 60-50-75.txt
# Type3Big 200-20-30.txt
# Type3Big 200-30-45.txt
# Type3Big 200-40-60.txt
# Type3Big 200-50-80.txt
# Type3Big 400-20-30.txt
# Type3Big 400-30-45.txt
# Type3Big 400-40-60.txt
# Type3Big 400-50-80.txt
# Type3Big 600-20-30.txt
# Type3Big 600-30-45.txt
# Type3Big 600-40-60.txt
# Type3Big 600-50-80.txt
# Type3Big 800-20-30.txt
# Type3Big 800-30-45.txt
# Type3Big 800-40-60.txt
# Type3Big 800-50-80.txt
# Type4Small 10-10-15.txt
# Type4Small 10-20-30.txt
# Type4Small 10-35-50.txt
# Type4Small 10-50-75.txt
# Type4Small 20-10-15.txt
# Type4Small 20-20-30.txt
# Type4Small 20-35-50.txt
# ...
