# %%
# !gdown 18rTK7bN9WsVRj7a2LxscFrU9WU28vbPh # download data sử dụng gdown
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=18rTK7bN9WsVRj7a2LxscFrU9WU28vbPh
# To: /content/data.zip
# 100% 1.35M/1.35M [00:00<00:00, 198MB/s]

# %%
pip install ortools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ortools
#   Downloading ortools-9.3.10497-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.5 MB)
#      |████████████████████████████████| 15.5 MB 14.2 MB/s
# Requirement already satisfied: absl-py>=0.13 in /usr/local/lib/python3.7/dist-packages (from ortools) (1.1.0)
# Collecting protobuf>=3.19.4
#   Downloading protobuf-4.21.2-cp37-abi3-manylinux2014_x86_64.whl (407 kB)
#      |████████████████████████████████| 407 kB 61.8 MB/s
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from ortools) (1.21.6)
# Installing collected packages: protobuf, ortools
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.2+zzzcolab20220527125636 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.21.2 which is incompatible.
# tensorflow-metadata 1.9.0 requires protobuf<4,>=3.13, but you have protobuf 4.21.2 which is incompatible.
# google-cloud-bigquery-storage 1.1.2 requires protobuf<4.0.0dev, but you have protobuf 4.21.2 which is incompatible.
# google-api-core 1.31.6 requires protobuf<4.0.0dev,>=3.12.0; python_version > "3", but you have protobuf 4.21.2 which is incompatible.
# Successfully installed ortools-9.3.10497 protobuf-4.21.2

# %%
from ortools.linear_solver import pywraplp
import json
import timeit

# %%
# upload file data.zip lên colab 
import shutil
set_N = [4, 5, 6, 7, 8, 9, 10, 15, 20, 30, 50, 100, 200, 500, 1000, 5000, 10000, 50000, 100000, 200000] # các giá trị của N, data lưu trong data-N.json
shutil.unpack_archive('data.zip', '/content', 'zip')

# %%
def read_data(N=5): #hàm đọc data , input N, output N A C c a f m
    with open(f'data/data-{N}.json') as f:
        data = f.read()
    return json.loads(data)

# %%
def scip(N, A, C, c, a, f, m):
    solver = pywraplp.Solver.CreateSolver('SCIP')
    infinity = solver.infinity()

    k = {}
    for i in range(N):
        k[i] = solver.IntVar(m[i], infinity, f'k_{i}')

    solver.Add(sum((k[i]*c[i]) for i in range(N)) <= C)
    solver.Add(sum((k[i]*a[i]) for i in range(N)) <= A)

    solver.Maximize(sum((k[i]*f[i]) for i in range(N)))
    status = solver.Solve()

    if status == pywraplp.Solver.OPTIMAL:
        # print('Runtime: '+str(stop - start))
        # print('Solution:')
        # print('Objective value =', solver.Objective().Value())
        # result=[]
        # for i in range(N):
        #     result.append(k[i].solution_value())
        return solver.Objective().Value()
    else:
        print('The problem does not have an optimal solution.')

# %%
scip_result = {}

for n in set_N:
  if n>100000:
    break
  print("Case :"+str(n))
  N, A, C, c, a, f, m = read_data(n)
  time_list=[]
  result_list=[]
  for i in range(10):
    print("Runtime: "+str(i))
    start = timeit.default_timer()
    result = scip(N, A, C, c, a, f, m)
    stop = timeit.default_timer()
    time_list.append(stop-start)
    result_list.append(result)
  if n not in scip_result:
    scip_result[n]={"time": time_list, "result": result_list}
# Out:
# Case :4
# Runtime: 0
# Runtime: 1
# Runtime: 2
# Runtime: 3
# Runtime: 4
# Runtime: 5
# Runtime: 6
# Runtime: 7
# Runtime: 8
# Runtime: 9
# Case :5
# Runtime: 0
# Runtime: 1
# Runtime: 2
# Runtime: 3
# Runtime: 4
# Runtime: 5
# Runtime: 6
# Runtime: 7
# Runtime: 8
# Runtime: 9
# Case :6
# Runtime: 0
# Runtime: 1
# Runtime: 2
# Runtime: 3
# Runtime: 4
# Runtime: 5
# Runtime: 6
# Runtime: 7
# Runtime: 8
# Runtime: 9
# Case :7
# Runtime: 0
# Runtime: 1
# Runtime: 2
# Runtime: 3
# Runtime: 4
# Runtime: 5
# Runtime: 6
# Runtime: 7
# Runtime: 8
# Runtime: 9
# Case :8
# Runtime: 0
# Runtime: 1
# Runtime: 2
# Runtime: 3
# Runtime: 4
# Runtime: 5
# Runtime: 6
# Runtime: 7
# Runtime: 8
# Runtime: 9
# Case :9
# Runtime: 0
# Runtime: 1
# Runtime: 2
# Runtime: 3
# Runtime: 4
# Runtime: 5
# Runtime: 6
# Runtime: 7
# Runtime: 8
# Runtime: 9
# Case :10
# Runtime: 0
# Runtime: 1
# Runtime: 2
# Runtime: 3
# Runtime: 4
# Runtime: 5
# Runtime: 6
# Runtime: 7
# Runtime: 8
# Runtime: 9
# Case :15
# Runtime: 0
# Runtime: 1
# Runtime: 2
# Runtime: 3
# Runtime: 4
# Runtime: 5
# Runtime: 6
# Runtime: 7
# Runtime: 8
# Runtime: 9
# Case :20
# Runtime: 0
# Runtime: 1
# Runtime: 2
# Runtime: 3
# Runtime: 4
# Runtime: 5
# Runtime: 6
# Runtime: 7
# Runtime: 8
# Runtime: 9
# Case :30
# Runtime: 0
# Runtime: 1
# Runtime: 2
# Runtime: 3
# Runtime: 4
# Runtime: 5
# Runtime: 6
# Runtime: 7
# Runtime: 8
# Runtime: 9
# Case :50
# Runtime: 0
# Runtime: 1
# Runtime: 2
# Runtime: 3
# Runtime: 4
# Runtime: 5
# Runtime: 6
# Runtime: 7
# Runtime: 8
# Runtime: 9
# Case :100
# Runtime: 0
# Runtime: 1
# Runtime: 2
# Runtime: 3
# Runtime: 4
# Runtime: 5
# Runtime: 6
# Runtime: 7
# Runtime: 8
# Runtime: 9
# Case :200
# Runtime: 0
# Runtime: 1
# Runtime: 2
# Runtime: 3
# Runtime: 4
# Runtime: 5
# Runtime: 6
# Runtime: 7
# Runtime: 8
# Runtime: 9
# Case :500
# Runtime: 0
# Runtime: 1
# Runtime: 2
# Runtime: 3
# Runtime: 4
# Runtime: 5
# Runtime: 6
# Runtime: 7
# Runtime: 8
# Runtime: 9
# Case :1000
# Runtime: 0
# Runtime: 1
# Runtime: 2
# Runtime: 3
# Runtime: 4
# Runtime: 5
# Runtime: 6
# Runtime: 7
# Runtime: 8
# Runtime: 9
# Case :5000
# Runtime: 0
# Runtime: 1
# Runtime: 2
# Runtime: 3
# Runtime: 4
# Runtime: 5
# Runtime: 6
# Runtime: 7
# Runtime: 8
# Runtime: 9
# Case :10000
# Runtime: 0
# Runtime: 1
# Runtime: 2
# Runtime: 3
# Runtime: 4
# Runtime: 5
# Runtime: 6
# Runtime: 7
# Runtime: 8
# Runtime: 9
# Case :50000
# Runtime: 0
# Runtime: 1
# Runtime: 2
# Runtime: 3
# Runtime: 4
# Runtime: 5
# Runtime: 6
# Runtime: 7
# Runtime: 8
# Runtime: 9
# Case :100000
# Runtime: 0
# Runtime: 1
# Runtime: 2
# Runtime: 3
# Runtime: 4
# Runtime: 5
# Runtime: 6
# Runtime: 7
# Runtime: 8
# Runtime: 9

# %%
from google.colab import drive
drive.mount('/content/drive')
with open(f'/content/drive/MyDrive/Báo cáo/Tối ưu lập kế hoạch - Nhóm 3/result/scip.json', 'w') as f:
      json.dump(scip_result, f)
# Out:
# Mounted at /content/drive
