# %%
# requirements.txt
# !cp ./drive/MyDrive/Academic/cplex_studio2210.linux_x86_64.bin ./
# !chmod u+x ./cplex_studio2210.linux_x86_64.bin
# !./cplex_studio2210.linux_x86_64.bin
# install CPLEX via setup.py

# %% [markdown]
# Drive path to ```/ibm```: https://drive.google.com/drive/folders/1zUIlliuQhfSQK45JnF4B9OuQgBShN55-?usp=sharing (Add this folder to drive shortcut)

# %%
# !python './drive/MyDrive/ibm/ILOG/CPLEX_Studio221/python/setup.py' install
# !python './drive/MyDrive/Academic/ibm/ILOG/CPLEX_Studio221/python/setup.py' install
# Out:
# ['/content/drive/MyDrive/ibm/ILOG/CPLEX_Studio221/cplex/python/3.7/x86-64_linux/cplex']
# ['/content/drive/MyDrive/ibm/ILOG/CPLEX_Studio221/cplex/python/3.7/x86-64_linux/setup.py']
# Invoking ['/usr/bin/python3', 'setup.py', 'install'] in /content/drive/MyDrive/ibm/ILOG/CPLEX_Studio221/cplex/python/3.7/x86-64_linux
# /usr/lib/python3.7/distutils/dist.py:274: UserWarning: Unknown distribution option: 'zip_safe'
#   warnings.warn(msg)
# running install
# running build
# running build_py
# running install_lib
# creating /usr/local/lib/python3.7/dist-packages/cplex
# copying build/lib/cplex/model_info.py -> /usr/local/lib/python3.7/dist-packages/cplex
# copying build/lib/cplex/paramset.py -> /usr/local/lib/python3.7/dist-packages/cplex
# copying build/lib/cplex/aborter.py -> /usr/local/lib/python3.7/dist-packages/cplex
# copying build/lib/cplex/constant_class.py -> /usr/local/lib/python3.7/dist-packages/cplex
# copying build/lib/cplex/callbacks.py -> /usr/local/lib/python3.7/dist-packages/cplex
# copying build/lib/cplex/__init__.py -> /usr/local/lib/python3.7/dist-packages/cplex
# creating /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/_callbackinfoenum.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/_baseinterface.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/_anno.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/libcplex2210.so -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/_list_array_utils.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/_constantsenum.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/_constants.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/py37_cplex2210.so -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/_aux_functions.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/_parameter_hierarchy.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/_solutionstrategyenum.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/_ostream.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/__init__.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/_multiobj.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/_parameter_classes.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/_pycplex.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/_parameters_auto.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/_pwl.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/_pycplex_platform.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/_multiobjsoln.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/_matrices.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/_subinterfaces.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# copying build/lib/cplex/_internal/_procedural.py -> /usr/local/lib/python3.7/dist-packages/cplex/_internal
# creating /usr/local/lib/python3.7/dist-packages/cplex/exceptions
# copying build/lib/cplex/exceptions/error_codes.py -> /usr/local/lib/python3.7/dist-packages/cplex/exceptions
# copying build/lib/cplex/exceptions/errors.py -> /usr/local/lib/python3.7/dist-packages/cplex/exceptions
# copying build/lib/cplex/exceptions/__init__.py -> /usr/local/lib/python3.7/dist-packages/cplex/exceptions
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/model_info.py to model_info.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/paramset.py to paramset.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/aborter.py to aborter.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/constant_class.py to constant_class.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/callbacks.py to callbacks.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/__init__.py to __init__.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/_callbackinfoenum.py to _callbackinfoenum.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/_baseinterface.py to _baseinterface.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/_anno.py to _anno.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/_list_array_utils.py to _list_array_utils.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/_constantsenum.py to _constantsenum.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/_constants.py to _constants.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/_aux_functions.py to _aux_functions.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/_parameter_hierarchy.py to _parameter_hierarchy.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/_solutionstrategyenum.py to _solutionstrategyenum.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/_ostream.py to _ostream.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/__init__.py to __init__.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/_multiobj.py to _multiobj.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/_parameter_classes.py to _parameter_classes.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/_pycplex.py to _pycplex.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/_parameters_auto.py to _parameters_auto.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/_pwl.py to _pwl.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/_pycplex_platform.py to _pycplex_platform.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/_multiobjsoln.py to _multiobjsoln.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/_matrices.py to _matrices.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/_subinterfaces.py to _subinterfaces.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/_internal/_procedural.py to _procedural.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/exceptions/error_codes.py to error_codes.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/exceptions/errors.py to errors.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/cplex/exceptions/__init__.py to __init__.cpython-37.pyc
# running install_egg_info
# Writing /usr/local/lib/python3.7/dist-packages/cplex-22.1.0.0.egg-info
# Installing certifi-2019.9.11
#    Unpack: /content/drive/MyDrive/ibm/ILOG/CPLEX_Studio221/python/dependencies/python/certifi-2019.9.11.tar.gz in /tmp/tmpe27p32x8
#    Installing from /tmp/tmpe27p32x8/certifi-2019.9.11
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:484: UserWarning: Normalizing '2019.09.11' to '2019.9.11'
#   warnings.warn(tmpl.format(**locals()))
# running install
# running bdist_egg
# running egg_info
# writing certifi.egg-info/PKG-INFO
# writing dependency_links to certifi.egg-info/dependency_links.txt
# writing top-level names to certifi.egg-info/top_level.txt
# reading manifest file 'certifi.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# adding license file 'LICENSE'
# writing manifest file 'certifi.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/certifi
# copying certifi/__init__.py -> build/lib/certifi
# copying certifi/__main__.py -> build/lib/certifi
# copying certifi/core.py -> build/lib/certifi
# copying certifi/cacert.pem -> build/lib/certifi
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/certifi
# copying build/lib/certifi/__init__.py -> build/bdist.linux-x86_64/egg/certifi
# copying build/lib/certifi/cacert.pem -> build/bdist.linux-x86_64/egg/certifi
# copying build/lib/certifi/__main__.py -> build/bdist.linux-x86_64/egg/certifi
# copying build/lib/certifi/core.py -> build/bdist.linux-x86_64/egg/certifi
# byte-compiling build/bdist.linux-x86_64/egg/certifi/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/certifi/__main__.py to __main__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/certifi/core.py to core.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying certifi.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying certifi.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying certifi.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying certifi.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying certifi.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating dist
# creating 'dist/certifi-2019.9.11-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing certifi-2019.9.11-py3.7.egg
# creating /usr/local/lib/python3.7/dist-packages/certifi-2019.9.11-py3.7.egg
# Extracting certifi-2019.9.11-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding certifi 2019.9.11 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/certifi-2019.9.11-py3.7.egg
# Processing dependencies for certifi==2019.9.11
# Finished processing dependencies for certifi==2019.9.11
# Installing chardet-3.0.4
#    Unpack: /content/drive/MyDrive/ibm/ILOG/CPLEX_Studio221/python/dependencies/python/chardet-3.0.4.tar.gz in /tmp/tmp3ty3wy9m
#    Installing from /tmp/tmp3ty3wy9m/chardet-3.0.4
# running install
# running bdist_egg
# running egg_info
# writing chardet.egg-info/PKG-INFO
# writing dependency_links to chardet.egg-info/dependency_links.txt
# writing entry points to chardet.egg-info/entry_points.txt
# writing top-level names to chardet.egg-info/top_level.txt
# reading manifest file 'chardet.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'requirements.txt'
# adding license file 'LICENSE'
# writing manifest file 'chardet.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/chardet
# copying chardet/big5prober.py -> build/lib/chardet
# copying chardet/langhebrewmodel.py -> build/lib/chardet
# copying chardet/langturkishmodel.py -> build/lib/chardet
# copying chardet/sbcsgroupprober.py -> build/lib/chardet
# copying chardet/big5freq.py -> build/lib/chardet
# copying chardet/langcyrillicmodel.py -> build/lib/chardet
# copying chardet/charsetprober.py -> build/lib/chardet
# copying chardet/cp949prober.py -> build/lib/chardet
# copying chardet/mbcharsetprober.py -> build/lib/chardet
# copying chardet/escprober.py -> build/lib/chardet
# copying chardet/universaldetector.py -> build/lib/chardet
# copying chardet/langhungarianmodel.py -> build/lib/chardet
# copying chardet/latin1prober.py -> build/lib/chardet
# copying chardet/eucjpprober.py -> build/lib/chardet
# copying chardet/utf8prober.py -> build/lib/chardet
# copying chardet/euctwfreq.py -> build/lib/chardet
# copying chardet/euckrfreq.py -> build/lib/chardet
# copying chardet/sjisprober.py -> build/lib/chardet
# copying chardet/version.py -> build/lib/chardet
# copying chardet/mbcssm.py -> build/lib/chardet
# copying chardet/__init__.py -> build/lib/chardet
# copying chardet/enums.py -> build/lib/chardet
# copying chardet/hebrewprober.py -> build/lib/chardet
# copying chardet/mbcsgroupprober.py -> build/lib/chardet
# copying chardet/gb2312prober.py -> build/lib/chardet
# copying chardet/gb2312freq.py -> build/lib/chardet
# copying chardet/sbcharsetprober.py -> build/lib/chardet
# copying chardet/langthaimodel.py -> build/lib/chardet
# copying chardet/codingstatemachine.py -> build/lib/chardet
# copying chardet/chardistribution.py -> build/lib/chardet
# copying chardet/langgreekmodel.py -> build/lib/chardet
# copying chardet/escsm.py -> build/lib/chardet
# copying chardet/euckrprober.py -> build/lib/chardet
# copying chardet/charsetgroupprober.py -> build/lib/chardet
# copying chardet/langbulgarianmodel.py -> build/lib/chardet
# copying chardet/jisfreq.py -> build/lib/chardet
# copying chardet/jpcntx.py -> build/lib/chardet
# copying chardet/compat.py -> build/lib/chardet
# copying chardet/euctwprober.py -> build/lib/chardet
# creating build/lib/chardet/cli
# copying chardet/cli/chardetect.py -> build/lib/chardet/cli
# copying chardet/cli/__init__.py -> build/lib/chardet/cli
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/big5prober.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/langhebrewmodel.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/langturkishmodel.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/sbcsgroupprober.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/big5freq.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/langcyrillicmodel.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/charsetprober.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/cp949prober.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/mbcharsetprober.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/escprober.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/universaldetector.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/langhungarianmodel.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/latin1prober.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/eucjpprober.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/utf8prober.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/euctwfreq.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/euckrfreq.py -> build/bdist.linux-x86_64/egg/chardet
# creating build/bdist.linux-x86_64/egg/chardet/cli
# copying build/lib/chardet/cli/chardetect.py -> build/bdist.linux-x86_64/egg/chardet/cli
# copying build/lib/chardet/cli/__init__.py -> build/bdist.linux-x86_64/egg/chardet/cli
# copying build/lib/chardet/sjisprober.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/version.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/mbcssm.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/__init__.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/enums.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/hebrewprober.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/mbcsgroupprober.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/gb2312prober.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/gb2312freq.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/sbcharsetprober.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/langthaimodel.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/codingstatemachine.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/chardistribution.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/langgreekmodel.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/escsm.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/euckrprober.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/charsetgroupprober.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/langbulgarianmodel.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/jisfreq.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/jpcntx.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/compat.py -> build/bdist.linux-x86_64/egg/chardet
# copying build/lib/chardet/euctwprober.py -> build/bdist.linux-x86_64/egg/chardet
# byte-compiling build/bdist.linux-x86_64/egg/chardet/big5prober.py to big5prober.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/langhebrewmodel.py to langhebrewmodel.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/langturkishmodel.py to langturkishmodel.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/sbcsgroupprober.py to sbcsgroupprober.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/big5freq.py to big5freq.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/langcyrillicmodel.py to langcyrillicmodel.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/charsetprober.py to charsetprober.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/cp949prober.py to cp949prober.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/mbcharsetprober.py to mbcharsetprober.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/escprober.py to escprober.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/universaldetector.py to universaldetector.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/langhungarianmodel.py to langhungarianmodel.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/latin1prober.py to latin1prober.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/eucjpprober.py to eucjpprober.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/utf8prober.py to utf8prober.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/euctwfreq.py to euctwfreq.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/euckrfreq.py to euckrfreq.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/cli/chardetect.py to chardetect.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/cli/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/sjisprober.py to sjisprober.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/version.py to version.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/mbcssm.py to mbcssm.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/enums.py to enums.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/hebrewprober.py to hebrewprober.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/mbcsgroupprober.py to mbcsgroupprober.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/gb2312prober.py to gb2312prober.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/gb2312freq.py to gb2312freq.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/sbcharsetprober.py to sbcharsetprober.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/langthaimodel.py to langthaimodel.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/codingstatemachine.py to codingstatemachine.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/chardistribution.py to chardistribution.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/langgreekmodel.py to langgreekmodel.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/escsm.py to escsm.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/euckrprober.py to euckrprober.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/charsetgroupprober.py to charsetgroupprober.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/langbulgarianmodel.py to langbulgarianmodel.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/jisfreq.py to jisfreq.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/jpcntx.py to jpcntx.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/compat.py to compat.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/chardet/euctwprober.py to euctwprober.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying chardet.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying chardet.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying chardet.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying chardet.egg-info/entry_points.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying chardet.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/chardet-3.0.4-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing chardet-3.0.4-py3.7.egg
# Copying chardet-3.0.4-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding chardet 3.0.4 to easy-install.pth file
# Installing chardetect script to /usr/local/bin
#
# Installed /usr/local/lib/python3.7/dist-packages/chardet-3.0.4-py3.7.egg
# Processing dependencies for chardet==3.0.4
# Finished processing dependencies for chardet==3.0.4
# Installing idna-2.8
#    Unpack: /content/drive/MyDrive/ibm/ILOG/CPLEX_Studio221/python/dependencies/python/idna-2.8.tar.gz in /tmp/tmp2ivdpi8s
#    Installing from /tmp/tmp2ivdpi8s/idna-2.8
# running install
# running bdist_egg
# running egg_info
# writing idna.egg-info/PKG-INFO
# writing dependency_links to idna.egg-info/dependency_links.txt
# writing top-level names to idna.egg-info/top_level.txt
# reading manifest file 'idna.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no previously-included files matching '*.pyc' found under directory 'tools'
# warning: no previously-included files matching '*.pyc' found under directory 'tests'
# adding license file 'LICENSE.rst'
# writing manifest file 'idna.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/idna
# copying idna/idnadata.py -> build/lib/idna
# copying idna/uts46data.py -> build/lib/idna
# copying idna/package_data.py -> build/lib/idna
# copying idna/__init__.py -> build/lib/idna
# copying idna/codec.py -> build/lib/idna
# copying idna/core.py -> build/lib/idna
# copying idna/intranges.py -> build/lib/idna
# copying idna/compat.py -> build/lib/idna
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/idna
# copying build/lib/idna/idnadata.py -> build/bdist.linux-x86_64/egg/idna
# copying build/lib/idna/uts46data.py -> build/bdist.linux-x86_64/egg/idna
# copying build/lib/idna/package_data.py -> build/bdist.linux-x86_64/egg/idna
# copying build/lib/idna/__init__.py -> build/bdist.linux-x86_64/egg/idna
# copying build/lib/idna/codec.py -> build/bdist.linux-x86_64/egg/idna
# copying build/lib/idna/core.py -> build/bdist.linux-x86_64/egg/idna
# copying build/lib/idna/intranges.py -> build/bdist.linux-x86_64/egg/idna
# copying build/lib/idna/compat.py -> build/bdist.linux-x86_64/egg/idna
# byte-compiling build/bdist.linux-x86_64/egg/idna/idnadata.py to idnadata.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/idna/uts46data.py to uts46data.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/idna/package_data.py to package_data.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/idna/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/idna/codec.py to codec.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/idna/core.py to core.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/idna/intranges.py to intranges.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/idna/compat.py to compat.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying idna.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying idna.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying idna.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying idna.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/idna-2.8-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing idna-2.8-py3.7.egg
# Copying idna-2.8-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding idna 2.8 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/idna-2.8-py3.7.egg
# Processing dependencies for idna==2.8
# Finished processing dependencies for idna==2.8
# Installing six-1.12.0
#    Unpack: /content/drive/MyDrive/ibm/ILOG/CPLEX_Studio221/python/dependencies/python/six-1.12.0.tar.gz in /tmp/tmp5yyji7jo
#    Installing from /tmp/tmp5yyji7jo/six-1.12.0
# running install
# running bdist_egg
# running egg_info
# writing six.egg-info/PKG-INFO
# writing dependency_links to six.egg-info/dependency_links.txt
# writing top-level names to six.egg-info/top_level.txt
# reading manifest file 'six.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# no previously-included directories found matching 'documentation/_build'
# adding license file 'LICENSE'
# writing manifest file 'six.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# copying six.py -> build/lib
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# copying build/lib/six.py -> build/bdist.linux-x86_64/egg
# byte-compiling build/bdist.linux-x86_64/egg/six.py to six.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying six.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying six.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying six.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying six.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# __pycache__.six.cpython-37: module references __path__
# creating dist
# creating 'dist/six-1.12.0-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing six-1.12.0-py3.7.egg
# creating /usr/local/lib/python3.7/dist-packages/six-1.12.0-py3.7.egg
# Extracting six-1.12.0-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding six 1.12.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/six-1.12.0-py3.7.egg
# Processing dependencies for six==1.12.0
# Finished processing dependencies for six==1.12.0
# /usr/lib/python3.7/distutils/dist.py:274: UserWarning: Unknown distribution option: 'long_description_content_type'
#   warnings.warn(msg)
# /usr/lib/python3.7/distutils/dist.py:274: UserWarning: Unknown distribution option: 'install_requires'
#   warnings.warn(msg)
# running install
# running build
# running build_py
# running install_lib
# creating /usr/local/lib/python3.7/dist-packages/docplex
# copying build/lib/docplex/version.py -> /usr/local/lib/python3.7/dist-packages/docplex
# copying build/lib/docplex/__init__.py -> /usr/local/lib/python3.7/dist-packages/docplex
# creating /usr/local/lib/python3.7/dist-packages/docplex/cp
# copying build/lib/docplex/cp/parameters.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp
# copying build/lib/docplex/cp/check_list.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp
# copying build/lib/docplex/cp/expression.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp
# copying build/lib/docplex/cp/catalog.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp
# copying build/lib/docplex/cp/modeler.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp
# copying build/lib/docplex/cp/model.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp
# copying build/lib/docplex/cp/solution.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp
# copying build/lib/docplex/cp/function.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp
# copying build/lib/docplex/cp/config.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp
# copying build/lib/docplex/cp/blackbox.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp
# copying build/lib/docplex/cp/__init__.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp
# copying build/lib/docplex/cp/utils_visu.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp
# copying build/lib/docplex/cp/tokenizer.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp
# copying build/lib/docplex/cp/utils.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp
# creating /usr/local/lib/python3.7/dist-packages/docplex/cp/solver
# copying build/lib/docplex/cp/solver/cpo_callback.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp/solver
# copying build/lib/docplex/cp/solver/solver_local.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp/solver
# copying build/lib/docplex/cp/solver/solver.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp/solver
# copying build/lib/docplex/cp/solver/solver_lib.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp/solver
# copying build/lib/docplex/cp/solver/solver_listener.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp/solver
# copying build/lib/docplex/cp/solver/environment_client.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp/solver
# copying build/lib/docplex/cp/solver/__init__.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp/solver
# copying build/lib/docplex/cp/solver/solver_simulator.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp/solver
# creating /usr/local/lib/python3.7/dist-packages/docplex/cp/cpo
# copying build/lib/docplex/cp/cpo/cpo_compiler.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp/cpo
# copying build/lib/docplex/cp/cpo/cpo_parser.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp/cpo
# copying build/lib/docplex/cp/cpo/cpo_tokenizer.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp/cpo
# copying build/lib/docplex/cp/cpo/__init__.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp/cpo
# creating /usr/local/lib/python3.7/dist-packages/docplex/cp/fzn
# copying build/lib/docplex/cp/fzn/fzn_parser.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp/fzn
# copying build/lib/docplex/cp/fzn/__init__.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp/fzn
# copying build/lib/docplex/cp/fzn/fzn_tokenizer.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp/fzn
# creating /usr/local/lib/python3.7/dist-packages/docplex/cp/lp
# copying build/lib/docplex/cp/lp/lp_tokenizer.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp/lp
# copying build/lib/docplex/cp/lp/lp_parser.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp/lp
# copying build/lib/docplex/cp/lp/__init__.py -> /usr/local/lib/python3.7/dist-packages/docplex/cp/lp
# creating /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/ppretty.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/progress.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/priority.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/model_stats.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/vartype.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/cplex_adapter.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/linear.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/functional.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/kpi.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/mfactory.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/quad.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/operand.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/mprinter.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/constants.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/engine_factory.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/cplex_engine.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/relaxer.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/context.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/worker_utils.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/solsol.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/dvar.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/solution.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/solmst.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/conflict_refiner.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/basic.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/qprogress.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/environment.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/sosvarset.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/aggregator.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/engine.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/relax_linear.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/pwl.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/utils.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/sol_xml_reader.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/lp_printer.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/tck.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/anno.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/sumfn.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/solprinter.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/quadfact.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/format.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/publish.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/sttck.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/soljson.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/constr.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/with_funcs.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/advmodel.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/model.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/__init__.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/numutils.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/model_reader.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/solve_env.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/check_list.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/xcounter.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/ds_utils.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/sdetails.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# copying build/lib/docplex/mp/error_handler.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp
# creating /usr/local/lib/python3.7/dist-packages/docplex/mp/callbacks
# copying build/lib/docplex/mp/callbacks/cb_mixin.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/callbacks
# copying build/lib/docplex/mp/callbacks/__init__.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/callbacks
# creating /usr/local/lib/python3.7/dist-packages/docplex/mp/internal
# copying build/lib/docplex/mp/internal/mloader.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/internal
# copying build/lib/docplex/mp/internal/json_infeasibility_handler.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/internal
# copying build/lib/docplex/mp/internal/json_solution_handler.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/internal
# copying build/lib/docplex/mp/internal/__init__.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/internal
# copying build/lib/docplex/mp/internal/json_conflict_handler.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/internal
# creating /usr/local/lib/python3.7/dist-packages/docplex/mp/params
# copying build/lib/docplex/mp/params/parameter_hierarchy_121000.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/params
# copying build/lib/docplex/mp/params/parameter_hierarchy_22100.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/params
# copying build/lib/docplex/mp/params/parameter_hierarchy_12900.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/params
# copying build/lib/docplex/mp/params/parameters.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/params
# copying build/lib/docplex/mp/params/parameter_hierarchy_20100.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/params
# copying build/lib/docplex/mp/params/parameter_hierarchy_12800.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/params
# copying build/lib/docplex/mp/params/cplex_params.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/params
# copying build/lib/docplex/mp/params/__init__.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/params
# creating /usr/local/lib/python3.7/dist-packages/docplex/mp/sktrans
# copying build/lib/docplex/mp/sktrans/modeler.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/sktrans
# copying build/lib/docplex/mp/sktrans/cpx_mdlr.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/sktrans
# copying build/lib/docplex/mp/sktrans/__init__.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/sktrans
# copying build/lib/docplex/mp/sktrans/pd_utils.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/sktrans
# copying build/lib/docplex/mp/sktrans/transformers.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/sktrans
# copying build/lib/docplex/mp/sktrans/docplex_mdlr.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/sktrans
# creating /usr/local/lib/python3.7/dist-packages/docplex/mp/sparktrans
# copying build/lib/docplex/mp/sparktrans/spark_utils.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/sparktrans
# copying build/lib/docplex/mp/sparktrans/transformers.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/sparktrans
# copying build/lib/docplex/mp/sparktrans/__init__.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/sparktrans
# creating /usr/local/lib/python3.7/dist-packages/docplex/mp/worker
# copying build/lib/docplex/mp/worker/solve_hook.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/worker
# copying build/lib/docplex/mp/worker/worker_env.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/worker
# copying build/lib/docplex/mp/worker/__init__.py -> /usr/local/lib/python3.7/dist-packages/docplex/mp/worker
# creating /usr/local/lib/python3.7/dist-packages/docplex/util
# copying build/lib/docplex/util/csv_utils.py -> /usr/local/lib/python3.7/dist-packages/docplex/util
# copying build/lib/docplex/util/__init__.py -> /usr/local/lib/python3.7/dist-packages/docplex/util
# copying build/lib/docplex/util/environment.py -> /usr/local/lib/python3.7/dist-packages/docplex/util
# copying build/lib/docplex/util/status.py -> /usr/local/lib/python3.7/dist-packages/docplex/util
# copying build/lib/docplex/util/logging_utils.py -> /usr/local/lib/python3.7/dist-packages/docplex/util
# creating /usr/local/lib/python3.7/dist-packages/docplex/util/dods
# copying build/lib/docplex/util/dods/project_handler.py -> /usr/local/lib/python3.7/dist-packages/docplex/util/dods
# copying build/lib/docplex/util/dods/executor.py -> /usr/local/lib/python3.7/dist-packages/docplex/util/dods
# copying build/lib/docplex/util/dods/__init__.py -> /usr/local/lib/python3.7/dist-packages/docplex/util/dods
# creating /usr/local/lib/python3.7/dist-packages/docplex/util/ws
# copying build/lib/docplex/util/ws/__init__.py -> /usr/local/lib/python3.7/dist-packages/docplex/util/ws
# copying build/lib/docplex/util/ws/util.py -> /usr/local/lib/python3.7/dist-packages/docplex/util/ws
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/version.py to version.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/__init__.py to __init__.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/parameters.py to parameters.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/check_list.py to check_list.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/expression.py to expression.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/catalog.py to catalog.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/modeler.py to modeler.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/model.py to model.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/solution.py to solution.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/function.py to function.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/config.py to config.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/blackbox.py to blackbox.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/__init__.py to __init__.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/utils_visu.py to utils_visu.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/tokenizer.py to tokenizer.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/utils.py to utils.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/solver/cpo_callback.py to cpo_callback.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/solver/solver_local.py to solver_local.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/solver/solver.py to solver.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/solver/solver_lib.py to solver_lib.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/solver/solver_listener.py to solver_listener.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/solver/environment_client.py to environment_client.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/solver/__init__.py to __init__.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/solver/solver_simulator.py to solver_simulator.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/cpo/cpo_compiler.py to cpo_compiler.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/cpo/cpo_parser.py to cpo_parser.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/cpo/cpo_tokenizer.py to cpo_tokenizer.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/cpo/__init__.py to __init__.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/fzn/fzn_parser.py to fzn_parser.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/fzn/__init__.py to __init__.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/fzn/fzn_tokenizer.py to fzn_tokenizer.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/lp/lp_tokenizer.py to lp_tokenizer.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/lp/lp_parser.py to lp_parser.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/cp/lp/__init__.py to __init__.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/ppretty.py to ppretty.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/progress.py to progress.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/priority.py to priority.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/model_stats.py to model_stats.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/vartype.py to vartype.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/cplex_adapter.py to cplex_adapter.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/linear.py to linear.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/functional.py to functional.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/kpi.py to kpi.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/mfactory.py to mfactory.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/quad.py to quad.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/operand.py to operand.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/mprinter.py to mprinter.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/constants.py to constants.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/engine_factory.py to engine_factory.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/cplex_engine.py to cplex_engine.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/relaxer.py to relaxer.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/context.py to context.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/worker_utils.py to worker_utils.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/solsol.py to solsol.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/dvar.py to dvar.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/solution.py to solution.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/solmst.py to solmst.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/conflict_refiner.py to conflict_refiner.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/basic.py to basic.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/qprogress.py to qprogress.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/environment.py to environment.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/sosvarset.py to sosvarset.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/aggregator.py to aggregator.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/engine.py to engine.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/relax_linear.py to relax_linear.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/pwl.py to pwl.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/utils.py to utils.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/sol_xml_reader.py to sol_xml_reader.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/lp_printer.py to lp_printer.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/tck.py to tck.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/anno.py to anno.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/sumfn.py to sumfn.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/solprinter.py to solprinter.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/quadfact.py to quadfact.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/format.py to format.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/publish.py to publish.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/sttck.py to sttck.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/soljson.py to soljson.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/constr.py to constr.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/with_funcs.py to with_funcs.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/advmodel.py to advmodel.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/model.py to model.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/__init__.py to __init__.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/numutils.py to numutils.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/model_reader.py to model_reader.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/solve_env.py to solve_env.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/check_list.py to check_list.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/xcounter.py to xcounter.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/ds_utils.py to ds_utils.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/sdetails.py to sdetails.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/error_handler.py to error_handler.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/callbacks/cb_mixin.py to cb_mixin.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/callbacks/__init__.py to __init__.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/internal/mloader.py to mloader.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/internal/json_infeasibility_handler.py to json_infeasibility_handler.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/internal/json_solution_handler.py to json_solution_handler.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/internal/__init__.py to __init__.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/internal/json_conflict_handler.py to json_conflict_handler.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/params/parameter_hierarchy_121000.py to parameter_hierarchy_121000.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/params/parameter_hierarchy_22100.py to parameter_hierarchy_22100.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/params/parameter_hierarchy_12900.py to parameter_hierarchy_12900.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/params/parameters.py to parameters.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/params/parameter_hierarchy_20100.py to parameter_hierarchy_20100.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/params/parameter_hierarchy_12800.py to parameter_hierarchy_12800.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/params/cplex_params.py to cplex_params.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/params/__init__.py to __init__.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/sktrans/modeler.py to modeler.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/sktrans/cpx_mdlr.py to cpx_mdlr.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/sktrans/__init__.py to __init__.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/sktrans/pd_utils.py to pd_utils.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/sktrans/transformers.py to transformers.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/sktrans/docplex_mdlr.py to docplex_mdlr.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/sparktrans/spark_utils.py to spark_utils.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/sparktrans/transformers.py to transformers.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/sparktrans/__init__.py to __init__.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/worker/solve_hook.py to solve_hook.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/worker/worker_env.py to worker_env.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/mp/worker/__init__.py to __init__.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/util/csv_utils.py to csv_utils.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/util/__init__.py to __init__.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/util/environment.py to environment.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/util/status.py to status.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/util/logging_utils.py to logging_utils.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/util/dods/project_handler.py to project_handler.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/util/dods/executor.py to executor.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/util/dods/__init__.py to __init__.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/util/ws/__init__.py to __init__.cpython-37.pyc
# byte-compiling /usr/local/lib/python3.7/dist-packages/docplex/util/ws/util.py to util.cpython-37.pyc
# running install_egg_info
# Writing /usr/local/lib/python3.7/dist-packages/docplex-2.23.221.egg-info
# ** The documentation can be found here: http://ibmdecisionoptimization.github.io/docplex-doc/
# ** The examples can be found here: https://github.com/IBMDecisionOptimization/docplex-examples

# %% [markdown]
# ### Data Generation Guideline
# ------------------------------<br>
# N kind of items <br>
# M+1 points <br>
# q[i] number of item i to take <br>
# Q[i,j] number of item i at point j <br>
# d[i, j] distance from point i to j<br>
# ------------------------------<br>
# Decision variables: <br>
# x[j], go or not go to point j <br>
# y[i, j], go or not from i to j <br>
# ------------------------------<br>
# Constraint: <br>
# x[0]=1<br>
# y[i,i]=0, (i=0->m)<br>
# sum(y[i,j])=x[i], (i=0->m)<br>
# sum(y[i,j])=sum(y[j,i]), (i=0->m, j from 0 to m)<br>
# sum(Q[i,j]\*x[j])>=q[i], for every item i in request (j=1->m)<br>(Subtour Elimination) u[i] - u[j] + m\*y[i][j] <= m-1 <br>------------------------------<br>
# Optimize Objective: Minimize sum(y[i,j]*d[j,j])<br>

# %%
# total_data = get_json('./drive/MyDrive/Academic/IT4663/6_28_impossible_data.json')
# # assert len(total_data)>17
# json2txt(total_data,'./drive/MyDrive/Academic/IT4663/6_28_impossible_data')

# %% [markdown]
# ### Utils

# %%
import cplex
from cplex.exceptions import CplexError
import sys, json
import itertools

def findsubsets(s, n):
    return list(itertools.combinations(s, n))

def checkd(d):
    subs = findsubsets(range(len(d)),3)
    for a,b,c in subs:
        if d[a][b]>d[b][c]+d[c][a]:
            return False
    return True
    
def dump_json(test_data,output_json_name=None):
    if output_json_name is not None:
            with open(output_json_name, "w",encoding='utf8') as output_file:
                json.dump(test_data,output_file,ensure_ascii=False)

def get_json(path):
    with open(path,"r", encoding='utf8') as f:
        data=json.load(f)
    return data

def read_file(path):
    with open(path,'r') as f:
        d = f.read().strip()
    return d

def write_file(content,path):
    with open(path,'w') as f:
        f.write(content)

# %%
def read_raw_data_and_solve(str_path: str, output_txt_path: str = None):
    """
    str_path: Path to txt file containing raw data
    output_txt_path: Path to save txt file containing data with solution

    Return: Dict{
        ... // same as init_data_with_solution
    }
    """
    d = read_file(str_path).split('\n')
    for i, row in enumerate(d):
        if i==0:
            n,m = int(row.split()[0]),int(row.split()[1])
            itloc = [[0 for i in range(m+1)] for j in range(n+1)]
            d = [[0 for i in range(m+1)] for j in range(m+1)]
        elif i>=1 and i<=n:
            itloc[i] = [0]+[int(x) for x in row.split()]
        elif i>=n+1 and i<=n+1+m:
            d[i-n-1] = [int(x) for x in row.split()]
        elif i==n+m+2:
            item2take = [0]+[int(x) for x in row.split()]
        else:
            print("Warning! There are more than m+n+3 rows in input data")
            break

    itemavail = [sum(itloc[i][1:]) for i in range(n+1)]
    data = {'n':n,'m':m,'item2take':item2take,'d':d,'itloc':itloc,'itemavail':itemavail}
    solver = Solver(data)
    data.update({"optimal_path":solver.get_optimal_path(),
                "optimal_value":solver.get_optimal_value(),
                "explanation":solver.get_explanation(),
                    "CPLEX_solving_time":solver.get_solving_time()})
    
    if output_txt_path is not None:
        tmp = []
        tmp.append("{} {}".format(data['n'],data['m']))
        for i in range(1,data['n']+1):
            tmp.append(' '.join([str(x) for x in data['itloc'][i][1:]]))
        for i in range(data['m']+1):
            tmp.append(' '.join([str(x) for x in data['d'][i]]))
        assert len(data['item2take'])==data['n']+1
        tmp.append(' '.join([str(x) for x in data['item2take'][1:]]))
        tmp.append(' '.join([str(x) for x in data['optimal_path']]))
        tmp.append(str(data['optimal_value']))
        tmp.append(str(data['CPLEX_solving_time']))
        write_file('\n'.join(tmp),output_txt_path)
    
    return data

# %%
from typing import Dict, List, Union
import random
from tqdm.auto import tqdm
import os
from os.path import join, exists
import math
import numpy as np

def json2txt(json_path: Union[str,List], txt_folder: str):
    if isinstance(json_path,str):
        json_data = get_json(json_path)
    else:
        assert isinstance(json_path,list), "List of data points or path please!"
        json_data = json_path
    
    if not exists(txt_folder):
        os.makedirs(txt_folder)
    for idx,data in enumerate(json_data):
        tmp = []
        tmp.append("{} {}".format(data['n'],data['m']))
        for i in range(1,data['n']+1):
            tmp.append(' '.join([str(x) for x in data['itloc'][i][1:]]))
        for i in range(data['m']+1):
            tmp.append(' '.join([str(x) for x in data['d'][i]]))
        assert len(data['item2take'])==data['n']+1
        tmp.append(' '.join([str(x) for x in data['item2take'][1:]]))
        # The last 3 lines are optimal path, optimal value and solving time (in seconds)
        if 'optimal_path' in data:
            tmp.append(' '.join([str(x) for x in data['optimal_path']]))
            tmp.append(str(data['optimal_value']))
            tmp.append(str(data['CPLEX_solving_time']))
        write_file('\n'.join(tmp),join(txt_folder,f'case_{idx}.txt'))

def get_rand_point(bound):
    tmp = [random.randint(0,bound),random.randint(0,bound)]
    while tmp==[0,0]:
        tmp = [random.randint(0,bound),random.randint(0,bound)]
    return tmp

def calc_eucli(a,b):
    # return math.sqrt((a[0]-b[0])**2+(a[1]-b[1])**2)
    return np.linalg.norm(np.array(a)-np.array(b))

# %%
def init_raw_data(n: int, m: int, low: int, high: int, bound: int, symmetric: bool = True,
                  take_percent: float=1.0, loop:bool=True, **kwargs) -> Dict:
    """
    Init raw data without solution
    ------
    n: number of types of items
    m: number of locations containing items (shelves, but excluding starting point)
    low: minimum number of item of each kind contained in a shelf
    high: maximum number of item of each kind contained in a shelf
    """
    itloc = [[random.randint(low,high) for i in range(m+1)] for j in range(n+1)] # (n+1)*(m+1) item-location matrix
    xys = [[0,0]]+[get_rand_point(bound) for _ in range(m)]
    assert len(xys)==m+1
    if not loop:
        d = [[calc_eucli(xys[i],xys[j]) for i in range(m+1)] for j in range(m+1)]
    else:
        d = [[random.randint(1,bound) for i in range(m+1)] for j in range(m+1)] # (m+1)*(m+1) distance matrix
    for i in range(m+1): # distance to same loc = 0
        d[i][i]=0
    for i in range(m+1): # placeholder line
        itloc[0][i]=0
    for i in range(1,n+1): # base contains no item
        itloc[i][0]=0
    if symmetric:
        for i in range(m):
            for j in range(i+1, m+1):
                d[i][j] = d[j][i]
    itemavail = [sum(itloc[i][1:]) for i in range(n+1)]
    item2take = [random.randint(0,int(take_percent*itemavail[i])) for i in range(n+1)] # generate random requests
    return {'n':n,'m':m,'low':low,'high':high,
        'itloc':itloc, 'd':d, 'itemavail':itemavail,'item2take':item2take}

def init_data_with_solution(n: int, m: int, low: int, high: int, bound: int , 
                            percent_usage: float=0.5, return_solver: bool=False, 
                            symmetric: bool=True, take_percent: float=1.0, loop:bool=True, **kwargs) -> Dict:
    """
    Init data with solution
    ------
    n: number of types of items
    m: number of locations containing items (shelves, but excluding starting point)
    low: minimum number of item of each kind contained in a shelf
    high: maximum number of item of each kind contained in a shelf
    take_percent: max percentage of each item in request
    percent_usage: if < 1.0, generate data such that optimal solution will include 
                   visits of no more than the same percentage of locations
                   e.g. percent_usage = 0.5 -> optimal_path will only include up to 50% locations

    Return: Dict{
        'n':n,
        'm':m,
        'd': distance matrix,
        'item2take': (n+1) matrix, where index [i] indicates
                     quantity of item i to take in request,
        'itloc': (n+1)*(m+1) matrix, where index [i][j] indicates
                number of item i at point j (i=1->n , j=1->m)
        'itemavail': (n+1) matrix, where index [i] indicates total number of item i available
        'optimal_path': optimal path found by CPLEX,
        'optimal_value': optimal value found by CPLEX (minimum total path distance),
        'explanation': explanation for solution,
        'CPLEX_solving_time': CPLEX solving time (seconds)
    }
    """

    tq = tqdm(desc='Trying ...')
    while True:
        data = init_raw_data(n,m,low,high,bound, symmetric, take_percent,loop)
        solver = Solver(data)
        data.update({"optimal_path":solver.get_optimal_path(),
                    "optimal_value":solver.get_optimal_value(),
                    "explanation":solver.get_explanation(),
                     "CPLEX_solving_time":solver.get_solving_time()})
        data.pop('low',None)
        data.pop('high',None)
        data.pop('bound',None)
        tq.update(1)
        if percent_usage<1.0 and len(data['optimal_path'])-2>int(data['m']*percent_usage):
            continue
        break
    tq.close()
    if return_solver:
        return [data, solver]
    return data

# %% [markdown]
# ### CPLEX Solver

# %%
from typing import Dict, List
import cplex
import time, math

class Solver:
    """
    Solver that handles data with UNLIMITED decision variables (well, solving time gets escalated quickly)
    """
    def __init__(self, data: Dict):
        for k,v in data.items():
            setattr(self, k, v)
        self.data = data
        self.init_problem()
        self.init_constraint()
        self.solve()
        self.recheck()
        # print(f"Case with {self.n} kinds of item and {self.m} container locations")
        # print("Number of decision variables",len(self.prob.variables.get_lower_bounds()))

    def init_problem(self):
        self.prob = cplex.Cplex()
        m=self.m
        # x[j]
        self.prob.variables.add(names=[f"x_{j}" for j in range(1,m+1)],
                            types=[self.prob.variables.type.binary for j in range(1,m+1)])
        # y[i,j]
        self.prob.variables.add(names=[f"y_{i}_{j}" \
                                    for i in range(m+1) for j in range(m+1) if i!=j],
                            types=[self.prob.variables.type.binary \
                                for i in range(m+1) for j in range(m+1) if i!=j])
        # u[i]
        self.prob.variables.add(names=[f"u_{i}" for i in range(1,m+1)],
                                types=[self.prob.variables.type.continuous for i in range(1,m+1)])
        for u_var in [f"u_{i}" for i in range(1,m+1)]:
            self.prob.variables.set_lower_bounds(u_var, 1.0)
            self.prob.variables.set_upper_bounds(u_var, m)

        self.prob.objective.set_linear([(f"y_{i}_{j}",self.d[i][j])\
                             for i in range(m+1)\
                             for j in range(m+1) if i!=j])
        self.prob.objective.set_sense(self.prob.objective.sense.minimize)

    def init_constraint(self):
        # sum(y[i,j])=x[i], (i=0->m)
        m=self.m
        n=self.n
        for i in range(0,m+1):
            self.prob.linear_constraints.add(
                lin_expr= [cplex.SparsePair(ind= [f"y_{i}_{j}" for j in range(0,m+1) if j!=i]+[f"x_{i}"]\
                                            if i!=0 else [f"y_{i}_{j}" for j in range(0,m+1) if j!=i], \
                                            val= [1 for j in range(0,m+1) if j!=i]+[-1]\
                                            if i!=0 else [1 for j in range(0,m+1) if j!=i])],
                rhs= [0] if i!=0 else [1],
                names = ["Moving constraint (1)-{}".format(i)],
                senses = ['E']
            )
        # sum(y[i,j])=sum(y[j,i]), (i=0->m)
        for i in range(0,m+1):
            self.prob.linear_constraints.add(
                lin_expr= [cplex.SparsePair(ind= [f"y_{i}_{j}" for j in range(0,m+1) if j!=i]+\
                                                [f"y_{j}_{i}" for j in range(0,m+1) if j!=i], \
                                            val= [1 for j in range(0,m+1) if j!=i]+\
                                                [-1 for j in range(0,m+1) if j!=i])],
                rhs= [0],
                names = ["Moving constraint (2)-{}".format(i)],
                senses = ['E']
            )
        # subtour elimination
        # i.e. u[i] + m*y[i][j] - u[j] <= m - 1
        for i in range(1,m+1):
            for j in range(1,m+1):
                if i==j:
                    continue
                self.prob.linear_constraints.add(
                    lin_expr=[cplex.SparsePair(ind=[f"u_{i}",f"y_{i}_{j}",f"u_{j}"],
                                               val=[1,m,-1])],
                    rhs=[m-1],
                    names = ["Subtour elimination -{}".format(i)],
                    senses = ['L']
                )
        # sum(Q[i,j]*x[j])>=q[i]
        for i in range(1,n+1):
            self.prob.linear_constraints.add(
                lin_expr=[cplex.SparsePair(ind=[f"x_{j}" for j in range(1,m+1)],
                                        val=[self.itloc[i][j] for j in range(1,m+1)])],
                rhs = [self.item2take[i]],
                names = ["Item taken satisfied-{}".format(i)],
                senses = ['G']
            )

    def solve(self):
        self.prob.set_log_stream(None)
        self.prob.set_results_stream(None)
        st = time.time()
        self.prob.solve()
        self.solve_time = time.time()-st
        self.x_opt = [self.roundt(self.prob.solution.get_values(f"x_{i}")) if i!=0 else 1 for i in range(self.m+1)]
        self.y_opt = [[self.roundt(self.prob.solution.get_values(f"y_{i}_{j}")) if i!=j else 0 for j in range(self.m+1)] for i in range(self.m+1)]
        self.optimal_path = self.get_path(self.y_opt,self.m)
        self.optimal_value = sum([self.d[self.optimal_path[i]][self.optimal_path[i+1]] for i in range(len(self.optimal_path)-1)])
        self.cplex_optimal_value = self.prob.solution.get_objective_value()

    def get_optimal_value(self) -> int:
        return self.optimal_value

    def get_optimal_path(self) -> List[int]:
        return self.optimal_path    

    def get_solving_time(self) -> float:
        """
        Return solving time in seconds
        """
        return self.solve_time

    def get_path(self, y_opt: List[List[int]]=None, m: int=None):
        m, y_opt = self.m, self.y_opt
        path = [[i,j] for i in range(m+1) for j in range(m+1) if y_opt[i][j]!=0]
        # print(path)
        start = 0
        dest = {}
        dest.update(path)
        prev = start
        pathtoget = [prev]
        while dest[prev]!=start:
            pathtoget.append(dest[prev])
            prev=dest[prev]
        return pathtoget + [start]

    def recheck(self):
        assert abs(self.cplex_optimal_value-self.optimal_value)<1e-6,\
               [self.cplex_optimal_value,self.optimal_value]
        for i in range(self.m+1):
            for j in range(self.m+1):
                if self.y_opt[i][j]!=0:
                    assert i in self.optimal_path, "Subtour detected!"
                    assert j in self.optimal_path, "Subtour detected!"

    def roundt(self, x):
        assert (x<1e-6) or (x>0.9999)
        return 0 if x<1e-6 else 1

    def explain(self):
        print(self.get_explanation())
    
    def get_explanation(self,data: Dict = None, x_opt: List[int] = None, y_opt: List[List[int]] = None):
        if data is None:
            data, x_opt, y_opt = self.data, self.x_opt, self.y_opt
        n, m, itloc = data['n'], data['m'], data['itloc']
        itemavail, d, item2take = data['itemavail'], data['d'], data['item2take']
        path = self.get_path(y_opt,m)
        distance_cost =[d[path[i]][path[i+1]] for i in range(len(path)-1)]
        INFO = []
        INFO.append("EXPLANATION")
        INFO.append("="*30)
        INFO.append("Path of the packager: {}".format(" -> ".join(map(str,path))))
        INFO.append("Distance of path: {}".format(" + ".join(map(str,distance_cost)))\
                    + " = {}".format(sum(distance_cost)))
        INFO.append("-"*30)
        INFO.append("The packager need to take: ")
        for i in range(1,n+1):
            INFO.append("\tItem {} - Quantity: {}".format(i,item2take[i]))
            INFO.append("\tHe visits places containing the item: {}".format\
                        (" - ".join(["{} ({})".format(j,itloc[i][j]) for j in path[1:-1] if itloc[i][j]!=0])))
            INFO.append("\tHe could take a quantity of up to {}, which satisfies request".\
                        format(sum([itloc[i][j] for j in path[1:-1]])))
        INFO.append("-"*30)
        INFO.append("Thus, the optimal value is {}".format(sum(distance_cost)))
        return "\n".join(INFO)

# %%
# # prProb.set_results_stream(None)
# prProb.solve()
# print("Objective value:",prProb.solution.get_objective_value())
# print("\n"+"="*20+" decision variables "+"="*20)
# # optimal variables
# import math
# x_opt = [int(prProb.solution.get_values(f"x_{i}")) if i!=0 else 1 for i in range(m+1) ]
# y_opt = [[int(prProb.solution.get_values(f"y_{i}_{j}")) if i!=j else 0 for j in range(m+1)] for i in range(m+1)]
# for i in range(m+1):
    # if i!=0:
        # print(f"x_{i}",prProb.solution.get_values(f"x_{i}"))
    # for j in range(m+1):
    #     if j!=i:
    #         val = prProb.solution.get_values(f"y_{i}_{j}")
    #         assert math.ceil(val)==y_opt[i][j], ((i,j),val,y_opt[i][j])
    #         if val!=0:
    #             print(f"y_{i}_{j}",val)

# %% [markdown]
# ### Playground (test)

# %%
data_args = {'n':20,
             'm':20,
             'low':0,
             'high':10,
             'bound':100,
             'take_percent':0.5,
             'percent_usage':1.0, # max % shelves allowed
             'loop':False,
             'symmetric':True,
             'return_solver':False}

data = init_data_with_solution(**data_args)
print(data.keys())
print('Number of kinds of items:',data['n'])
print('Number of locations excluding base:',data['m'])
print('Request:',data['item2take'][1:])
print('Quantity available per item:',data['itemavail'][1:])
print("Distance matrix:",data['d'])
print("Optimal value:",data['optimal_value'])
print("Optimal path:",data['optimal_path'])
print("Number of shelves visited (excluding base):",len(data['optimal_path'])-2)
print()
# print(data['explanation'])
print("Solving time: {}(s)".format(data['CPLEX_solving_time']))
# data = init_raw_data(**data_args)
# Out:
# Trying ...: 0it [00:00, ?it/s]
# dict_keys(['n', 'm', 'itloc', 'd', 'itemavail', 'item2take', 'optimal_path', 'optimal_value', 'explanation', 'CPLEX_solving_time'])
# Number of kinds of items: 20
# Number of locations excluding base: 20
# Request: [6, 13, 5, 40, 3, 49, 23, 43, 10, 17, 32, 37, 23, 9, 1, 31, 18, 17, 21, 20]
# Quantity available per item: [106, 75, 101, 110, 78, 100, 116, 101, 99, 104, 93, 115, 101, 117, 89, 117, 94, 90, 94, 83]
# Distance matrix: [[0, 133.00375934536586, 74.94664769020693, 70.9365914038728, 103.58571330062848, 110.27692415006868, 82.20097323024831, 49.09175083453431, 88.48163651289458, 86.76404785393545, 123.00406497347964, 61.91122676865643, 26.40075756488817, 83.24061508662703, 104.4030650891055, 96.17692030835673, 56.92099788303083, 95.0, 92.13576938409967, 59.61543424315552, 51.62363799656123], [133.00375934536586, 0, 75.69015788066504, 75.27283706623525, 44.04543109109048, 41.19465984809196, 78.64477096412705, 102.95630140987001, 50.32891812864648, 56.302753041036986, 25.298221281347036, 73.60027173862879, 106.77546534667971, 70.09279563550022, 31.78049716414141, 36.87817782917155, 84.72307831990054, 39.96248240537617, 86.14522621712709, 79.92496481075234, 81.46778504415104], [74.94664769020693, 75.69015788066504, 0, 5.385164807134504, 34.132096331752024, 40.0, 80.61017305526642, 30.4138126514911, 26.076809620810597, 63.28506932918696, 56.43580423808985, 48.60041152089147, 55.08175741568164, 73.7563556583431, 60.67124524847005, 45.17742799230607, 60.90155991434045, 53.85164807134504, 94.76286192385707, 57.14017850864661, 36.05551275463989], [70.9365914038728, 75.27283706623525, 5.385164807134504, 0, 35.4682957019364, 41.72529209005013, 75.69015788066504, 28.600699292150182, 25.0, 59.0592922409336, 57.42821606144492, 43.41658669218482, 50.24937810560445, 69.02897942168927, 58.137767414994535, 43.01162633521314, 55.569775957799216, 50.80354318352215, 89.87213138676528, 51.86520991955976, 30.675723300355934], [103.58571330062848, 44.04543109109048, 34.132096331752024, 35.4682957019364, 0, 6.708203932499369, 80.05623023850174, 64.03124237432849, 16.278820596099706, 56.79788728465171, 22.360679774997898, 57.0, 79.7057087039567, 71.30918594402827, 41.10960958218893, 27.202941017470888, 71.00704190430693, 39.408120990476064, 92.61209424259879, 66.03029607687671, 54.70831746635972], [110.27692415006868, 41.19465984809196, 40.0, 41.72529209005013, 6.708203932499369, 0, 84.77027781009096, 70.178344238091, 22.80350850198276, 61.09828148156051, 17.46424919657298, 63.071388124885914, 86.4060183089118, 75.8946638440411, 43.278170016764804, 30.870698080866262, 77.02596964660685, 42.941821107167776, 96.93296652842108, 72.00694410957877, 61.35144660071187], [82.20097323024831, 78.64477096412705, 80.61017305526642, 75.69015788066504, 80.05623023850174, 84.77027781009096, 0, 85.492689745966, 66.64833081180653, 24.186773244895647, 85.37564055396598, 33.28663395418648, 60.03332407921454, 9.055385138137417, 48.093658625644196, 54.3415126767741, 27.294688127912362, 43.289721643826724, 14.212670403551895, 27.51363298439521, 50.53711507397311], [49.09175083453431, 102.95630140987001, 30.4138126514911, 28.600699292150182, 64.03124237432849, 70.178344238091, 85.492689745966, 0, 52.773099207835045, 75.8023746329889, 86.02325267042627, 52.81098370604357, 37.589892258425, 81.27115109311545, 82.03657720797473, 68.41052550594829, 59.682493245507096, 73.43704787094863, 99.28242543370907, 58.137767414994535, 35.11409973215888], [88.48163651289458, 50.32891812864648, 26.076809620810597, 25.0, 16.278820596099706, 22.80350850198276, 66.64833081180653, 52.773099207835045, 0, 44.82186966202994, 34.713109915419565, 41.10960958218893, 63.953107821277925, 58.309518948453004, 35.73513677041127, 19.924858845171276, 55.14526271584895, 30.528675044947494, 79.92496481075234, 50.24937810560445, 38.62641583165593], [86.76404785393545, 56.302753041036986, 63.28506932918696, 59.0592922409336, 56.79788728465171, 61.09828148156051, 24.186773244895647, 75.8023746329889, 44.82186966202994, 0, 61.204574992397426, 25.709920264364882, 61.09828148156051, 15.132745950421556, 24.73863375370596, 30.364452901377952, 31.240998703626616, 19.1049731745428, 35.84689665786984, 27.459060435491963, 42.01190307520001], [123.00406497347964, 25.298221281347036, 56.43580423808985, 57.42821606144492, 22.360679774997898, 17.46424919657298, 85.37564055396598, 86.02325267042627, 34.713109915419565, 61.20457 ...
# Optimal value: 236.15007316482652
# Optimal path: [0, 16, 19, 6, 18, 13, 9, 11, 20, 12, 0]
# Number of shelves visited (excluding base): 9
#
# Solving time: 13.271570205688477(s)

# %%
# imp_combinations = [
#                 [100,200],
#                 [200,250],
#                 [250,300],
#                 [300,400]
#                 [400,450],
#                 [500,500],
#                 [600,600],
#                 [800,800],
#                 [800,1000]]
# combinations = [[10,5],
#                 [10,15],
#                 [15,20],
#                 [20,25],
                # [25,30],
                # [35,40],
                
combinations = [
                [35,60],
                [45,60],
                [50,100],
                [80,100],
                [80,150],
                [100,150]]

solvers = []
total_data = []
for n,m in combinations:
    percent_usage=1.0
    if m<150:
        take_percent=0.3
    else:
        take_percent=0.1
    data_args = {'n':n,
                'm':m,
                'low':0,
                'high':10,
                'bound':100,
                'take_percent':take_percent,
                'percent_usage':percent_usage,
                'symmetric':True,
                'return_solver':False}
    # data = init_raw_data(**data_args)
    data = init_data_with_solution(**data_args)
    # print(data['CPLEX_solving_time'])
    total_data.append(data)
    print('Number of locations excluding base:',data['m'])
    print("Optimal value:",data['optimal_value'])
    print("Optimal path:",data['optimal_path'])
    print("Number of shelves visited (excluding base):",len(data['optimal_path'])-2)
    # solvers.append(solver)
    # dump_json(total_data,'./drive/MyDrive/Academic/IT4663/6_28_impossible_data.json')
    dump_json(total_data,'./drive/MyDrive/Academic/IT4663/7_18_2_data.json')
    # print("Optimal value:",data['optimal_value'],solver.prob.solution.get_objective_value())

# print()
# solver.explain()
# Out:
# Trying ...: 0it [00:00, ?it/s]
# Number of locations excluding base: 30
# Optimal value: 264.16147250380254
# Optimal path: [0, 14, 4, 17, 19, 12, 16, 5, 18, 6, 25, 8, 27, 30, 3, 0]
# Number of shelves visited (excluding base): 14
# Trying ...: 0it [00:00, ?it/s]
# Number of locations excluding base: 40
# Optimal value: 232.95809547587888
# Optimal path: [0, 18, 28, 24, 8, 6, 40, 31, 26, 12, 33, 7, 35, 36, 34, 21, 13, 22, 10, 16, 0]
# Number of shelves visited (excluding base): 19
# Trying ...: 0it [00:00, ?it/s]

# %%
imp_combinations = [
                [200,200],
                [200,250],
                [250,300],
                [300,400]
                [400,450],
                [500,500],
                [600,600],
                [800,800],
                [800,1000]]
                
solvers = []
total_data = []
for n,m in imp_combinations:
    percent_usage=1.0
    if m<30:
        take_percent=0.8
    elif m<80:
        take_percent=0.5
    elif m<150:
        take_percent=0.3
    else:
        take_percent=0.1
    data_args = {'n':n,
                'm':m,
                'low':0,
                'high':10,
                'bound':100,
                'take_percent':take_percent,
                'percent_usage':percent_usage,
                'symmetric':True,
                'return_solver':False}
    data = init_raw_data(**data_args)
    # solvers.append(solver)
    dump_json(total_data,'./drive/MyDrive/Academic/IT4663/7_18_impossible_data.json')
    # dump_json(total_data,'./drive/MyDrive/Academic/IT4663/7_18_data.json')
    # print("Optimal value:",data['optimal_value'],solver.prob.solution.get_objective_value())

# print()
# solver.explain()

# %%
# total_data = []
# from tqdm.auto import tqdm
# for m in tqdm(range(5,31,5)):
# for n,m in [[10,15],[15,20],[20,30],[40,50],[50,100],[100,150],[100,200],[150,200],[200,300]]:
    # if m<50:
    #     pct=0.8
    # else:
    #     pct=1.0
    # data_args = {'n':n,
    #             'm':m,
    #             'low':0,
    #             'high':10,
    #             'bound':1000,
    #             'percent_usage':pct,
    #             'return_solver':True}
    # data, solver = init_data_with_solution(**data_args)
    # # data.update({'solver':solver})
    # total_data.append(data)

# %% [markdown]
# ### Use CPLEX for optimal solution (given data)

# %%
# Example
path_to_read = './drive/MyDrive/Academic/IT4663/6_26_new_data/case_10.txt'
path_to_save = './case_0.txt'
data = read_raw_data_and_solve(path_to_read,path_to_save)
print(data['optimal_path'])
print(data['optimal_value'])
print(data['CPLEX_solving_time'])
# print(data['explanation'])
# Out:
# Warning! There are more than m+n+3 rows in input data
# [0, 131, 37, 136, 93, 11, 68, 2, 5, 22, 88, 105, 64, 13, 118, 146, 8, 0]
# 18
# 19.944003343582153
